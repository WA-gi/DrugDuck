# %%
from pathlib import Path
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches
from rdkit import Chem
from rdkit.Chem import Descriptors, Draw, PandasTools

# %%
def calculate_ro5_properties(smiles):
    """
    Test if input molecule (SMILES) fulfills Lipinski's rule of five.

    Parameters
    ----------
    smiles : str
        SMILES for a molecule.

    Returns
    -------
    pandas.Series
        Molecular weight, number of hydrogen bond acceptors/donor and logP value
        and Lipinski's rule of five compliance for input molecule.
    """
    # RDKit molecule from SMILES
    molecule = Chem.MolFromSmiles(smiles)
    # Calculate Ro5-relevant chemical properties
    molecular_weight = Descriptors.ExactMolWt(molecule)
    n_hba = Descriptors.NumHAcceptors(molecule)
    n_hbd = Descriptors.NumHDonors(molecule)
    logp = Descriptors.MolLogP(molecule)
    # Check if Ro5 conditions fulfilled
    conditions = [molecular_weight <= 500, n_hba <= 10, n_hbd <= 5, logp <= 5]
    ro5_fulfilled = sum(conditions) >= 3
    # Return True if no more than one out of four conditions is violated
    return pd.Series(
        [molecular_weight, n_hba, n_hbd, logp, ro5_fulfilled],
        index=["molecular_weight", "n_hba", "n_hbd", "logp", "ro5_fulfilled"],
    )

# %%
molecules = pd.read_csv("Covid_data_lip_PIC50.csv")
print(molecules.shape)

test = molecules.astype(object) 
test.info()
# Out:
# (306, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Mol_BDB_ID           306 non-null    object
#  1   Smiles               306 non-null    object
#  2   IC50_nm              306 non-null    object
#  3   bioactivity_class    306 non-null    object
#  4   MW                   306 non-null    object
#  5   LogP                 306 non-null    object
#  6   NumHDonors           306 non-null    object
#  7   NumHAcceptors        306 non-null    object
#  8   NumHeteroatoms       306 non-null    object
#  9   NumRotatableBonds    306 non-null    object
#  10  NumValenceElectrons  306 non-null    object
#  11  NumAromaticRings     306 non-null    object
#  12  NumSaturatedRings    306 non-null    object
#  13  NumAliphaticRings    306 non-null    object
#  14  pIC50                306 non-null    object
# dtypes: object(15)
# memory usage: 36.0+ KB

# %%
# CHECK_OUTPUT
for name, smiles in zip(molecules["Mol_BDB_ID"], molecules["Smiles"]):
    print(f"Ro5 fulfilled for {name}: {calculate_ro5_properties(smiles)['ro5_fulfilled']}")
# Out:
# Ro5 fulfilled for 1074441: True
# Ro5 fulfilled for 1074558: True
# Ro5 fulfilled for 1074516: True
# Ro5 fulfilled for 1074541: True
# Ro5 fulfilled for 1074478: True
# Ro5 fulfilled for 1074475: True
# Ro5 fulfilled for 1074546: True
# Ro5 fulfilled for 1074537: True
# Ro5 fulfilled for 1074540: True
# Ro5 fulfilled for 1074513: True
# Ro5 fulfilled for 1074447: True
# Ro5 fulfilled for 1074559: True
# Ro5 fulfilled for 1074515: True
# Ro5 fulfilled for 1074536: True
# Ro5 fulfilled for 1074438: True
# Ro5 fulfilled for 1074563: True
# Ro5 fulfilled for 1074440: True
# Ro5 fulfilled for 1074545: True
# Ro5 fulfilled for 1074539: True
# Ro5 fulfilled for 1074512: True
# Ro5 fulfilled for 1074444: True
# Ro5 fulfilled for 1074543: True
# Ro5 fulfilled for 1074560: True
# Ro5 fulfilled for 1074550: True
# Ro5 fulfilled for 1074535: True
# Ro5 fulfilled for 1074551: True
# Ro5 fulfilled for 1074561: True
# Ro5 fulfilled for 1074555: True
# Ro5 fulfilled for 1074557: True
# Ro5 fulfilled for 1074505: True
# Ro5 fulfilled for 1074497: True
# Ro5 fulfilled for 1074443: True
# Ro5 fulfilled for 1074476: True
# Ro5 fulfilled for 1074569: True
# Ro5 fulfilled for 1074547: True
# Ro5 fulfilled for 1074496: True
# Ro5 fulfilled for 1074503: True
# Ro5 fulfilled for 1074542: True
# Ro5 fulfilled for 1074499: True
# Ro5 fulfilled for 1074461: True
# Ro5 fulfilled for 1074420: True
# Ro5 fulfilled for 1074437: True
# Ro5 fulfilled for 1074493: True
# Ro5 fulfilled for 1074408: True
# Ro5 fulfilled for 1074456: True
# Ro5 fulfilled for 1074500: True
# Ro5 fulfilled for 1074538: True
# Ro5 fulfilled for 1074459: True
# Ro5 fulfilled for 1074403: True
# Ro5 fulfilled for 1074492: True
# Ro5 fulfilled for 1074548: True
# Ro5 fulfilled for 1074495: True
# Ro5 fulfilled for 1074498: True
# Ro5 fulfilled for 1074502: True
# Ro5 fulfilled for 1074477: True
# Ro5 fulfilled for 1074467: True
# Ro5 fulfilled for 1074501: True
# Ro5 fulfilled for 1074494: True
# Ro5 fulfilled for 1074457: True
# Ro5 fulfilled for 1074554: True
# Ro5 fulfilled for 1074412: True
# Ro5 fulfilled for 1074469: True
# Ro5 fulfilled for 1074414: True
# Ro5 fulfilled for 1074491: True
# Ro5 fulfilled for 1074455: True
# Ro5 fulfilled for 1074490: True
# Ro5 fulfilled for 1074517: True
# Ro5 fulfilled for 1074562: True
# Ro5 fulfilled for 1074504: True
# Ro5 fulfilled for 1074415: True
# Ro5 fulfilled for 1074518: True
# Ro5 fulfilled for 1074468: True
# Ro5 fulfilled for 1074418: True
# Ro5 fulfilled for 1074519: True
# Ro5 fulfilled for 995808: True
# Ro5 fulfilled for 995755: True
# Ro5 fulfilled for 995776: True
# Ro5 fulfilled for 995748: True
# Ro5 fulfilled for 995778: True
# Ro5 fulfilled for 995805: True
# Ro5 fulfilled for 995797: True
# Ro5 fulfilled for 995792: True
# Ro5 fulfilled for 995770: True
# Ro5 fulfilled for 995789: True
# Ro5 fulfilled for 995781: True
# Ro5 fulfilled for 995801: True
# Ro5 fulfilled for 995782: True
# Ro5 fulfilled for 995730: True
# Ro5 fulfilled for 1073436: True
# Ro5 fulfilled for 1073983: True
# Ro5 fulfilled for 1073442: True
# Ro5 fulfilled for 1073583: True
# Ro5 fulfilled for 1073587: True
# Ro5 fulfilled for 1073594: True
# Ro5 fulfilled for 1073573: True
# Ro5 fulfilled for 1073558: True
# Ro5 fulfilled for 1073575: True
# Ro5 fulfilled for 1073569: True
# Ro5 fulfilled for 1073560: True
# Ro5 fulfilled for 1073566: True
# Ro5 fulfilled for 1073452: True
# Ro5 fulfilled for 1073598: True
# Ro5 fulfilled for 1073554: True
# Ro5 fulfilled for 1073585: True
# Ro5 fulfilled for 1073571: True
# Ro5 fulfilled for 1073556: True
# Ro5 fulfilled for 1073458: True
# Ro5 fulfilled for 1073456: True
# Ro5 fulfilled for 1073602: True
# Ro5 fulfilled for 1073985: True
# Ro5 fulfilled for 1073974: True
# Ro5 fulfilled for 1073984: True
# Ro5 fulfilled for 1073600: True
# Ro5 fulfilled for 1073469: True
# Ro5 fulfilled for 1073548: True
# Ro5 fulfilled for 1073471: True
# Ro5 fulfilled for 1073980: True
# Ro5 fulfilled for 1073596: True
# Ro5 fulfilled for 1073473: True
# Ro5 fulfilled for 1073590: True
# Ro5 fulfilled for 1073564: True
# Ro5 fulfilled for 1073967: True
# Ro5 fulfilled for 1073475: True
# Ro5 fulfilled for 1073968: True
# Ro5 fulfilled for 1073478: True
# Ro5 fulfilled for 1073562: True
# Ro5 fulfilled for 1073481: True
# Ro5 fulfilled for 1073482: True
# Ro5 fulfilled for 1073483: True
# Ro5 fulfilled for 1073486: True
# Ro5 fulfilled for 1073567: True
# Ro5 fulfilled for 1073552: True
# Ro5 fulfilled for 1073495: True
# Ro5 fulfilled for 1073493: True
# Ro5 fulfilled for 1073494: True
# Ro5 fulfilled for 1073491: True
# Ro5 fulfilled for 1073979: True
# Ro5 fulfilled for 1073498: True
# Ro5 fulfilled for 1073465: True
# Ro5 fulfilled for 1073497: True
# Ro5 fulfilled for 1073502: False
# Ro5 fulfilled for 1073591: True
# Ro5 fulfilled for 1073654: True
# Ro5 fulfilled for 1073668: True
# Ro5 fulfilled for 1073507: True
# Ro5 fulfilled for 1073508: True
# Ro5 fulfilled for 1073511: True
# Ro5 fulfilled for 1073513: True
# Ro5 fulfilled for 1073514: True
# Ro5 fulfilled for 1073515: True
# Ro5 fulfilled for 1073517: True
# Ro5 fulfilled for 1073518: True
# Ro5 fulfilled for 1073520: True
# Ro5 fulfilled for 1073592: True
# Ro5 fulfilled for 1073522: True
# Ro5 fulfilled for 1073523: False
# Ro5 fulfilled for 1073526: True
# Ro5 fulfilled for 1073528: True
# Ro5 fulfilled for 1073529: True
# Ro5 fulfilled for 1073680: True
# Ro5 fulfilled for 1073533: True
# Ro5 fulfilled for 1073537: True
# Ro5 fulfilled for 1073538: True
# Ro5 fulfilled for 1073663: True
# Ro5 fulfilled for 1073676: True
# Ro5 fulfilled for 1073540: True
# Ro5 fulfilled for 1073541: True
# Ro5 fulfilled for 1073664: True
# Ro5 fulfilled for 1073577: True
# Ro5 fulfilled for 1073550: True
# Ro5 fulfilled for 1073606: True
# Ro5 fulfilled for 1073677: True
# Ro5 fulfilled for 1073611: True
# Ro5 fulfilled for 1073612: True
# Ro5 fulfilled for 1073613: True
# Ro5 fulfilled for 1073580: True
# Ro5 fulfilled for 1073614: True
# Ro5 fulfilled for 1073619: False
# Ro5 fulfilled for 1073616: True
# Ro5 fulfilled for 1073617: True
# Ro5 fulfilled for 1073618: True
# Ro5 fulfilled for 1073621: True
# Ro5 fulfilled for 1073981: True
# Ro5 fulfilled for 1073622: True
# Ro5 fulfilled for 1073684: True
# Ro5 fulfilled for 1073623: True
# Ro5 fulfilled for 1073625: True
# Ro5 fulfilled for 1073966: True
# Ro5 fulfilled for 1073666: True
# Ro5 fulfilled for 1073627: True
# Ro5 fulfilled for 1073665: True
# Ro5 fulfilled for 1073629: True
# Ro5 fulfilled for 1073631: True
# Ro5 fulfilled for 1073630: True
# Ro5 fulfilled for 1073635: True
# Ro5 fulfilled for 1073578: True
# Ro5 fulfilled for 1073637: True
# Ro5 fulfilled for 1073949: True
# Ro5 fulfilled for 1073678: True
# Ro5 fulfilled for 1073642: True
# Ro5 fulfilled for 1073667: True
# Ro5 fulfilled for 1073644: True
# Ro5 fulfilled for 1073646: True
# Ro5 fulfilled for 1073645: False
# Ro5 fulfilled for 1073662: True
# Ro5 fulfilled for 1073982: True
# Ro5 fulfilled for 1073683: True
# Ro5 fulfilled for 1073648: True
# Ro5 fulfilled for 1073581: True
# Ro5 fulfilled for 1073588: True
# Ro5 fulfilled for 1073686: True
# Ro5 fulfilled for 1073651: False
# Ro5 fulfilled for 1073679: True
# Ro5 fulfilled for 1073656: True
# Ro5 fulfilled for 1073530: True
# Ro5 fulfilled for 1073661: True
# Ro5 fulfilled for 1073673: True
# Ro5 fulfilled for 1073681: True
# Ro5 fulfilled for 1073659: True
# Ro5 fulfilled for 1073690: True
# Ro5 fulfilled for 1073691: True
# Ro5 fulfilled for 1073695: True
# Ro5 fulfilled for 1073693: True
# Ro5 fulfilled for 1073551: True
# Ro5 fulfilled for 1073700: True
# Ro5 fulfilled for 1073674: True
# Ro5 fulfilled for 1073682: True
# Ro5 fulfilled for 1073701: True
# Ro5 fulfilled for 1073703: True
# Ro5 fulfilled for 1073702: True
# Ro5 fulfilled for 854336: True
# Ro5 fulfilled for 1034008: True
# Ro5 fulfilled for 1034009: True
# Ro5 fulfilled for 1034012: True
# Ro5 fulfilled for 989766: True
# Ro5 fulfilled for 1034010: True
# Ro5 fulfilled for 1034011: True
# Ro5 fulfilled for 989788: True
# Ro5 fulfilled for 868641: True
# Ro5 fulfilled for 1108811: True
# Ro5 fulfilled for 1108807: True
# Ro5 fulfilled for 854406: True
# Ro5 fulfilled for 1034018: True
# Ro5 fulfilled for 1034019: True
# Ro5 fulfilled for 1033961: True
# Ro5 fulfilled for 854351: True
# Ro5 fulfilled for 854372: True
# Ro5 fulfilled for 1033990: True
# Ro5 fulfilled for 1033962: True
# Ro5 fulfilled for 1108835: True
# Ro5 fulfilled for 854378: True
# Ro5 fulfilled for 854347: True
# Ro5 fulfilled for 1033992: True
# Ro5 fulfilled for 854349: True
# Ro5 fulfilled for 1033949: True
# Ro5 fulfilled for 1003431: True
# Ro5 fulfilled for 1033993: True
# Ro5 fulfilled for 1033965: True
# Ro5 fulfilled for 1033950: True
# Ro5 fulfilled for 868701: True
# Ro5 fulfilled for 854395: True
# Ro5 fulfilled for 854353: True
# Ro5 fulfilled for 1033963: True
# Ro5 fulfilled for 868846: True
# Ro5 fulfilled for 868573: False
# Ro5 fulfilled for 854397: True
# Ro5 fulfilled for 868656: True
# Ro5 fulfilled for 854393: True
# Ro5 fulfilled for 854391: True
# Ro5 fulfilled for 1033952: True
# Ro5 fulfilled for 854389: True
# Ro5 fulfilled for 854361: True
# Ro5 fulfilled for 1108831: True
# Ro5 fulfilled for 989756: True
# Ro5 fulfilled for 1108815: True
# Ro5 fulfilled for 868787: True
# Ro5 fulfilled for 1003433: True
# Ro5 fulfilled for 1033995: True
# Ro5 fulfilled for 854411: True
# Ro5 fulfilled for 854366: True
# Ro5 fulfilled for 854357: True
# Ro5 fulfilled for 854415: True
# Ro5 fulfilled for 1033997: True
# Ro5 fulfilled for 854359: True
# Ro5 fulfilled for 1003432: True
# Ro5 fulfilled for 854342: True
# Ro5 fulfilled for 854370: True
# Ro5 fulfilled for 854387: True
# Ro5 fulfilled for 854368: True
# Ro5 fulfilled for 854401: True
# Ro5 fulfilled for 1108839: True
# Ro5 fulfilled for 1034021: True
# Ro5 fulfilled for 1108819: True
# Ro5 fulfilled for 854380: True
# Ro5 fulfilled for 868783: True
# Ro5 fulfilled for 868647: True
# Ro5 fulfilled for 854403: True
# Ro5 fulfilled for 854381: True
# Ro5 fulfilled for 854385: True
# Ro5 fulfilled for 51201273: True
# Ro5 fulfilled for 868654: True
# Ro5 fulfilled for 1033981: True
# Ro5 fulfilled for 989758: True
# Ro5 fulfilled for 868855: True
# Ro5 fulfilled for 1129710: False
# Ro5 fulfilled for 1108827: True

# %%
ro5_properties = molecules["Smiles"].apply(calculate_ro5_properties)
ro5_properties
# Out:
#      molecular_weight  n_hba  n_hbd     logp  ro5_fulfilled
# 0          531.109658      6      1  4.25408           True
# 1          441.120382      7      1  2.34980           True
# 2          505.115080      6      1  4.60730           True
# 3          505.115080      6      1  4.60730           True
# 4          523.105658      6      1  4.90290           True
# ..                ...    ...    ...      ...            ...
# 301        600.294785      6      4  3.41810           True
# 302        572.321000      7      4  2.59860           True
# 303        426.044106      6      0  4.45432           True
# 304        381.176067     11      6 -2.06280          False
# 305        445.152825      6      3  0.93132           True
#
# [306 rows x 5 columns]

# %%
molecules = pd.concat([molecules, ro5_properties], axis=1)
molecules.to_csv('Covid_active_ro5.csv')

# %%
molecules_ro5_fulfilled = molecules[molecules["ro5_fulfilled"]]
molecules_ro5_violated = molecules[~molecules["ro5_fulfilled"]]

print(f"# Total compounds in the data set: {molecules.shape[0]}")
print(f"# compounds fulfilled role of 5 : {molecules_ro5_fulfilled.shape[0]}")
print(f"# compounds not compliant with the Ro5: {molecules_ro5_violated.shape[0]}")
# Out:
# # Total compounds in the data set: 306
# # compounds fulfilled role of 5 : 299
# # compounds not compliant with the Ro5: 7

# %%
def calculate_mean_std(dataframe):
    """
    Calculate the mean and standard deviation of a dataset.

    Parameters
    ----------
    dataframe : pd.DataFrame
        Properties (columns) for a set of items (rows).

    Returns
    -------
    pd.DataFrame
        Mean and standard deviation (columns) for different properties (rows).
    """
    # Generate descriptive statistics for property columns
    stats = dataframe.describe()
    # Transpose DataFrame (statistical measures = columns)
    stats = stats.T
    # Select mean and standard deviation
    stats = stats[["mean", "std"]]
    return stats

# %%
molecules_ro5_fulfilled_stats = calculate_mean_std(
    molecules_ro5_fulfilled[["molecular_weight", "n_hba", "n_hbd", "logp"]]
)
molecules_ro5_fulfilled_stats
# Out:
#                         mean        std
# molecular_weight  457.539307  98.183315
# n_hba               5.578595   1.376825
# n_hbd               2.163880   1.675895
# logp                2.713353   1.353642

# %%
molecules_ro5_violated_stats = calculate_mean_std(
    molecules_ro5_violated[["molecular_weight", "n_hba", "n_hbd", "logp"]]
)
molecules_ro5_violated_stats
# Out:
#                         mean         std
# molecular_weight  581.971551  146.248272
# n_hba               9.571429    4.859943
# n_hbd               6.142857    1.069045
# logp               -0.157937    2.486295

# %%
def _scale_by_thresholds(stats, thresholds, scaled_threshold):
    """
    Scale values for different properties that have each an individually defined threshold.

    Parameters
    ----------
    stats : pd.DataFrame
        Dataframe with "mean" and "std" (columns) for each physicochemical property (rows).
    thresholds : dict of str: int
        Thresholds defined for each property.
    scaled_threshold : int or float
        Scaled thresholds across all properties.

    Returns
    -------
    pd.DataFrame
        DataFrame with scaled means and standard deviations for each physiochemical property.
    """
    # Raise error if scaling keys and data_stats indicies are not matching
    for property_name in stats.index:
        if property_name not in thresholds.keys():
            raise KeyError(f"Add property '{property_name}' to scaling variable.")
    # Scale property data
    stats_scaled = stats.apply(lambda x: x / thresholds[x.name] * scaled_threshold, axis=1)
    return stats_scaled
